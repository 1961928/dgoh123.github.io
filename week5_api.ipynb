# %% [markdown]
# <a href="https://colab.research.google.com/github/1961928/dgoh123.github.io/blob/main/week5_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url_base = "https://api.ons.gov.uk/timeseries/{}/dataset/PUSF/data"

# %%
ons_series = ['KSE6', 'CPMU', 'CPMV', 'CPMW', 'CPMX', 'CPMY', 'CPMZ', 'CPNA', 'CPNB']

for i in ons_series:  
   URL = url_base.format(i)
   print(URL)
# Out:
# https://api.ons.gov.uk/timeseries/KSE6/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPMU/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPMV/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPMW/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPMX/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPMY/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPMZ/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPNA/dataset/PUSF/data
# https://api.ons.gov.uk/timeseries/CPNB/dataset/PUSF/data

# %%
import requests

import json

from google.colab import files

import os

# %%
url = "https://api.ons.gov.uk/timeseries/KSE6/dataset/PUSF/data"

data = requests.get(url).json()

data
# Out:
# {'description': {'cdid': 'KSE6',
#   'contact': {'email': 'public.sector.inquiries@ons.gov.uk',
#    'name': 'Fraser Munro',
#    'telephone': '+44 1633 456402'},
#   'datasetId': 'PUSF',
#   'datasetUri': '/economy/governmentpublicsectorandtaxes/publicsectorfinance/datasets/publicsectorfinances',
#   'date': '2022 OCT',
#   'nextRelease': '21 December 2022',
#   'number': '2459868',
#   'preUnit': '',
#   'releaseDate': '2022-11-22T00:00:00.000Z',
#   'sampleSize': '0',
#   'source': '',
#   'title': 'PSNDX (millions)',
#   'unit': ''},
#  'months': [{'date': '1975 MAR',
#    'label': '1975 MAR',
#    'month': 'March',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2015-10-20T23:00:00.000Z',
#    'value': '52098',
#    'year': '1975'},
#   {'date': '1975 APR',
#    'label': '1975 APR',
#    'month': 'April',
#    'quarter': '',
#    'sourceDataset': 'PUSF',
#    'updateDate': '2015-10-20T23:00:00.000Z',
#    'value': '',
#    'year': '1975'},
# ...

# %%
fileName = "data_ons-KSE6.json"
print(fileName)

with open(fileName, 'w', encoding='utf-8') as f:
      json.dump(data, f, ensure_ascii=False, indent=4)


      files.download('data_ons-KSE6.json')
# Out:
# data_ons-KSE6.json

# %%
url_base = "https://api.ons.gov.uk/timeseries/{}/dataset/PUSF/data"

file_base =  "data_ons-{}.json"

ons_series = ['KSE6', 'CPMU', 'CPMV', 'CPMW', 'CPMX', 'CPMY', 'CPMZ', 'CPNA', 'CPNB']

for i in ons_series:  
  print("----------iteration starts--------")
  print(i)

  URL = url_base.format(i)
  print(URL)

  data = requests.get(URL).json()
  print(data)
  fileName = file_base.format(i)
  print(fileName)

  print("------interation ends------")

  with open(fileName, 'w', encoding='utf-8') as f:
     json.dump(data, f, ensure_ascii=False, indent=4)

  files.download(fileName)
# Out:
# ----------iteration starts--------
# KSE6
# https://api.ons.gov.uk/timeseries/KSE6/dataset/PUSF/data
# ...
